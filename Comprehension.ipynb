# %%
l = [1,2,3,4,5,6]
l1= []
for i  in l:
  l1.append(i**2)
l1
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
[i**2 for i  in l]
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
[i for i  in l if i%2==0]
# Out:
# [2, 4, 6]

# %%
l1 = ["asit","amit","kumar"]
[i.upper() for i  in l1 ]
# Out:
# ['ASIT', 'AMIT', 'KUMAR']

# %%
l2 =[1, 2, 3, 4, 5, 6]
list(i**2 for i  in l2)
# Out:
# [1, 4, 9, 16, 25, 36]

# %% [markdown]
# Dictionary Compression

# %%
d={"key1":2,"key2":3,"key3":4}
{k:v**2 for k,v in d.items()}
# Out:
# {'key1': 4, 'key2': 9, 'key3': 16}

# %%
d={"key1":2,"key2":3,"key3":4}
{k:v for k,v in d.items() if v>1}
# Out:
# {'key1': 2, 'key2': 3, 'key3': 4}
