# %%
def test():
  print("this  is  my  first  program of  function ")

# %%
test()
# Out:
# this  is  my  first  program of  function

# %%
def test1 ():
  return"Asit Kumar "

test1() + "Amit Kumar "
# Out:
# 'Asit Kumar Amit Kumar '

# %%
def test3():
  return "asit",543,434,4

test3()
# Out:
# ('asit', 543, 434, 4)

# %%
a,b,c,d = test3()

# %%
a
# Out:
# 'asit'

# %%
def test4():
  a = 3*4+5
  return a
test4()
# Out:
# 17

# %%
def  test5(a,b,c):
  d = a+b/c
  return d

test5(1,2,3)
# Out:
# 1.6666666666666665

# %%
def test6(a,b):
  return a+b

test6(1,2)
# Out:
# 3

# %%
test6("asit","kumar")
# Out:
# 'asitkumar'

# %%
test6([1,2,3,4],[5,6,7,8,9])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
l = [1,2,3,4,5,6,7,8,"Asit ","Amit",[1,2,3,4,5]]
# without  function  use  to find integer

li= []
for i  in l:
  if type(i)== int or type(i)==float:
    li.append(i)

li
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# Using  Function

def test7(a):
  l1 =[]
  for i in  a:
      if type(i)== int or type(i)==float:
         li.append(i)
  return li
a = [23,34,34,53,2,4,"Asit ","Amit",[1,2,3,4,5]]
test7(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 23, 34, 34, 53, 2, 4]

# %%
def test8(a):
  l=[]
  for i  in a:
    if type(i) == list:
      for j in i:
        l.append(j)
    else:
      if type(i) == int or type(i) == float:
        l.append(i)
  return l
a = [23,34,34,53,2,4,"Asit ","Amit",[1,2,3,4,5]]
test8(a)
# Out:
# [23, 34, 34, 53, 2, 4, 1, 2, 3, 4, 5]

# %%
def test9(a):
  """ This is my function  to  extact  numeric deta  from the list """

  l=[]
  for i  in a:
    if type(i) == list:
      for j in i:
        l.append(j)
    else:
      if type(i) == int or type(i) == float:
        l.append(i)
  return l
a = [23,34,34,53,2,4,"Asit ","Amit",[1,2,3,4,5]]
test9(a)
# Out:
# [23, 34, 34, 53, 2, 4, 1, 2, 3, 4, 5]

# %%
test9( )
# Out:
# [23, 34, 34, 53, 2, 4, 1, 2, 3, 4, 5]

# %%
def test10(a,b):
  return a+b

# %%
def test11(*args):
  return args
type(test11())
# Out:
# tuple

# %%
test11(1,2,3,4,"asmit", "asit","nikhil")
# Out:
# (1, 2, 3, 4, 'asmit', 'asit', 'nikhil')

# %%
def test12(*asit):
  return asit

test12(1,2,3,4,4)
# Out:
# (1, 2, 3, 4, 4)

# %%
def test13(*args , a):
  return args,a
test13(1,2,3,4,5)
# Out:
# ((1, 2, 3, 4), 5)

# %%
def test13(*args , a):
  return args,a
test13(1,2,3,4,a=5)
# Out:
# ((1, 2, 3, 4), 5)

# %%
def test14(c,d,a=23,b=1):
  return a,b,c,d

test14()
# Out:
# (23, 1, 3, 4)

# %%
test14(3,4)
# Out:
# (23, 1, 3, 4)

# %%
test14(2,5,a=2333)
# Out:
# (2333, 1, 2, 5)

# %%
def test15(**kwargs):
  return kwargs

test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a = [1,2,3,4],b = "asit",c = 23.45)
# Out:
# {'a': [1, 2, 3, 4], 'b': 'asit', 'c': 23.45}
