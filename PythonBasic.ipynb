# %% [markdown]
# Print  Function

# %%
print("Hello  World")
# Out:
# Hello  World

# %%
print("hello ",1,2,34, True)
# Out:
# hello  1 2 34 True

# %%
print("hello",1,2,34,True,sep="")
# Out:
# hello1234True

# %%
print("Hellow")
print("world")
# Out:
# Hellow
# world

# %%
print("asit",end='-')
print("world")
# Out:
# asit-world

# %% [markdown]
# # Data Types

# %%
# Integer
print(8);
# 1*10^309
print(1e309)
# Out:
# 8
# inf

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Decimal/ Float

print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
#String
print("Hello  World")
# Out:
# Hello  World

# %%
# Compleax

print(5+6j)
# Out:
# (5+6j)

# %%
#List
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#Dictionary

print({"name":"Asit","gender":"male","age":21})
# Out:
# {'name': 'Asit', 'gender': 'male', 'age': 21}

# %%
#set
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#type
type([1,2,3,4,5])
# Out:
# list

# %% [markdown]
# # **Variables**

# %%
#Ststic Vs  dynamic  typing
#ststic  vs  dynamic  binding
# stylish declartion techniques

# %%
name =  "Asit"
print(name)

a =5
b =10
print(a+b)
# Out:
# Asit
# 15

# %%
#dynamic  tyaing  pytohn
a =5
# static typing c /c++ / js
# int  a =  5
# Out:
#   File "/tmp/ipython-input-36-3220818013.py", line 4
#     int  a =  5
#          ^
# SyntaxError: invalid syntax

# %%
#Dynamic  Binding
a =  5
print(a)
a = "Asit"
print(a)

#Static  Binding
# int a = 5
# Out:
#   File "/tmp/ipython-input-37-4132349538.py", line 8
#     int a = 5
#         ^
# SyntaxError: invalid syntax

# %%
a,b,c =  1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c = 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # Comments

# %%
#This is  the  commeats
a = 5
b = 5
print(a+b)

 # pices  of  code  that  ignored  by  the  interpreter
# Out:
# 10

# %% [markdown]
# # Keywords $ Identifiears

# %%
#Keywords
#true  if  elase  finaaly  lambda  not  or  etc

#Identifire

#you  cant  start with  a  dighit
name1 = "Asit"
print(name1)

# you can  use  spaical  cahr
first_name = "Asit"
print(first_name)

#Identifirer  can  not  be  keywords
# Out:
# Asit
# Asit

# %% [markdown]
# # #User Input

# %%
#Static  Vs  Dynamic
input("Enter  the  number")
# Out:
# Enter  the  number3
# '3'

# %%
#Two  Sum  Program
# String  is  universal  data  format  that  is  defaut  store  python

a = int(input("Enter  the  first  number"))
b = int(input("Enter  the  second  number"))
print(a+b)
# Out:
# Enter  the  first  number5
# Enter  the  second  number33
# 38

# %% [markdown]
# #Type Conversion

# %%
# mplwcit vs  explicit
print(5+5.6)
print(type(5),type(5.6))

print(4+"4")
# Out:
# 10.6
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-45-2284399880.py in <cell line: 0>()
#       3 print(type(5),type(5.6))
#       4
# ----> 5 print(4+"4")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Explicit

type(int('4'))
int(4+5j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-47-1696389517.py in <cell line: 0>()
#       2
#       3 type(int('4'))
# ----> 4 int(4+5j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'
