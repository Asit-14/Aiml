# %% [markdown]
# #Input Function
# want  to  take  the  input  fomr  the  user  .  In  pytohn  we have the input()
#  function by  default it  takes as "str" datatypes

# %%
age = int(input("enter your age"))
# Out:
# enter your age45

# %%
age
# Out:
# 45

# %%
type(age)
# Out:
# int

# %%
int (age)+55
# Out:
# 100

# %% [markdown]
# #eval  function
# automatic  find  the  type  of the  variable

# %%
a =  eval(input("enter the value"))
# Out:
# enter the value55

# %%
type(a)
# Out:
# int

# %%
age  =  eval(input("enter  your  age"))
name =  input("enter  your  name")
print("hey !" , name , "your  age id ", age)
# Out:
# enter  your  age21
# enter  your  nameaSIT
# hey ! aSIT your  age id  21

# %%
b =  input("enter  your age")
str(int(b)+20)
# Out:
# enter  your age33
# '53'

# %% [markdown]
# # String  Indexing $ Slicing
# Slicing  is  to  extract  multiplae  charater

# %%
a =  "asit"
len(a)
# Out:
# 4

# %%
a[3]
# Out:
# 't'

# %%
a= 249877
str(a)
int(str(a)[2])
# Out:
# 9

# %%
b=  "pythonprogrammin"
b[0:4:2]
# Out:
# 'pt'

# %%
b[4:0:-1]
# Out:
# 'ohty'

# %%
b[0:1000:1]
# Out:
# 'pythonprogrammin'

# %%
s="What are you doing 🎉paddy"

# %%
s[0::3]
# Out:
# 'Wtry i ay'

# %%
s[0:10:-1]
# Out:
# ''

# %%
s[2:10]
# Out:
# 'at are y'

# %%
s[::-1]
# Out:
# 'yddap🎉 gniod uoy era tahW'
